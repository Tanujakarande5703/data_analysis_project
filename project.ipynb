# %% [markdown]
# Data analysis project

# %% [markdown]
# #### >> data collection
# #### >> data cleaning
# #### >> EDA (Exploratory Data Analysis)
# #### >> insight and conclusion

# %%
# india ecommerce sales and customer analysis using python

# %% [markdown]
# # India E-Commerce Sales & Customer Analytics Using Python
#
# **An end-to-end exploratory data analysis of 15,000+ online orders placed across 18 Indian states**
#
# ---
#
# | | |
# |---|---|
# | **Domain** | Retail / E-Commerce Analytics |
# | **Tools** | Python, NumPy, Pandas, Matplotlib, Seaborn, Plotly |
# | **Dataset** | `india_ecommerce_sales.csv` (synthetic, 15,120 rows x 29 columns) |
# | **Period covered** | 01-Jan-2024 to 31-Dec-2025 (24 months) |
# | **Currency** | Indian Rupee (INR) |
# | **Deliverables** | This notebook, a PDF report, a PowerPoint deck and exported charts |
#
# —

# %% [markdown]
# ## 1. Business Problem
#
# **BharatKart Retail Pvt. Ltd.** is a mid-sized Indian e-commerce marketplace selling across
# eight categories in 25 cities. Over the last two years the company has grown its top line
# aggressively through heavy festive discounting and rapid category expansion.
#
# Management is now facing an uncomfortable situation:
#
# > *"Revenue keeps growing, but profit is not growing at the same pace. We do not know which
# > categories, which regions and which customers are actually making money for us."*
#
# The leadership team cannot answer basic questions such as *which state is most profitable*,
# *how much margin our discounts destroy*, or *why our customer ratings are falling in some
# regions*. Decisions are being taken on intuition rather than evidence.
#
# This project analyses two full years of transactional data to convert that raw order log
# into a clear, quantified picture of where the business makes money, where it loses money,
# and what management should do next.

# %% [markdown]
# ## 2. Project Objectives
#
# 1. Load, inspect and **clean** a realistic (deliberately messy) transactional dataset.
# 2. Engineer time, customer and pricing features that make the data analysis-ready.
# 3. Compute the **core KPIs** management needs on a single page.
# 4. Run a structured **exploratory data analysis** (univariate, bivariate, multivariate).
# 5. Quantify **which categories, products, regions and customers drive revenue and profit**.
# 6. Measure the **impact of discounting** on profitability.
# 7. Measure the **impact of delivery performance** on customer satisfaction.
# 8. Map performance **geographically across India**.
# 9. Segment customers using an **RFM** model.
# 10. Convert every finding into **actionable business recommendations**.

# %% [markdown]
# ## 3. Dataset Description
#
# The file `data/india_ecommerce_sales.csv` is a **synthetic but statistically realistic**
# order log. Every row is one order line.
#
# ### Data dictionary
#
# | Column | Type | Description |
# |---|---|---|
# | `Order_ID` | object | Unique identifier of the order |
# | `Order_Date` | date | Date the order was placed |
# | `Customer_ID` | object | Unique identifier of the customer |
# | `Customer_Name` | object | Customer full name |
# | `Gender` | object | Male / Female |
# | `Age` | float | Age of the customer in years |
# | `Age_Group` | object | Age bucket (18-25, 26-35, 36-45, 46-60, 60+) |
# | `City` | object | Delivery city |
# | `State` | object | Delivery state |
# | `Region` | object | North / South / East / West / Central / Northeast |
# | `Latitude` | float | Latitude of the city (for mapping) |
# | `Longitude` | float | Longitude of the city (for mapping) |
# | `Product_ID` | object | Unique identifier of the product |
# | `Product_Name` | object | Product name |
# | `Category` | object | One of 8 merchandising categories |
# | `Sub_Category` | object | Sub-category within the category |
# | `Quantity` | int | Units ordered |
# | `Unit_Price` | float | Listed price per unit before discount (INR) |
# | `Discount_Percentage` | float | Discount applied on the order (%) |
# | `Sales` | float | Net booked revenue after discount (INR) |
# | `Cost` | float | Cost of goods sold (INR) |
# | `Profit` | float | Sales minus Cost, adjusted for returns (INR) |
# | `Profit_Margin` | float | Profit as a percentage of Sales |
# | `Payment_Method` | object | UPI, Credit Card, COD, EMI, ... |
# | `Order_Status` | object | Delivered / Shipped / Returned / Cancelled |
# | `Delivery_Days` | float | Days between order and delivery |
# | `Customer_Rating` | float | Post-delivery rating on a 1-5 scale |
# | `Customer_Segment` | object | Premium / Regular / Budget / Corporate |
# | `Device_Type` | object | Channel used to place the order |
#
# > **Note on synthetic data.** The dataset was produced by `scripts/generate_dataset.py`
# > with a fixed random seed, so every number in this notebook is reproducible. Realistic
# > behavioural patterns (festive peaks, discount-driven margin erosion, fashion returns,
# > delivery-rating relationship) were built into the generator; the analysis below
# > *discovers* them the same way it would on real data.

# %% [markdown]
# ## 4. Technologies Used
#
# | Library | Why it is used here |
# |---|---|
# | **NumPy** | Fast vectorised numeric work, percentiles, conditional flags |
# | **Pandas** | Loading, cleaning, grouping, pivoting, time-series resampling |
# | **Matplotlib** | Static charts for the report and presentation |
# | **Seaborn** | Statistical charts (distributions, box plots, heatmaps) |
# | **Plotly Express** | Interactive charts and the India geographic map |
# | **Jupyter Notebook** | The analysis environment itself |

# %%
# step-1 : Data Collection

# %%
# %pip install numpy pandas seaborn matplotlib
# Out:
# Requirement already satisfied: numpy in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.5.2)
# Requirement already satisfied: pandas in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.5)
# Requirement already satisfied: seaborn in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Tanuja\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Tanuja\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Tanuja\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (7.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\Users\Tanuja\AppData\Local\Programs\Python\Python314\Lib\site-packages (from plotly) (2.25.0)
# Requirement already satisfied: packaging in C:\Users\Tanuja\AppData\Roaming\Python\Python314\site-packages (from plotly) (26.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.express as px 
import plotly.graph_objects as go 
import json,os,warnings
from pathlib import Path 

pd.set_option("display.max_columns", 40)
pd.set_option("display.width", 160)
pd.set_option("display.float_format", lambda v: f"{v:,.2f}")

# %%
df_raw=pd.read_csv('india_ecommerce_sales.csv')

# %%
df_raw.head()
# Out:
#     Order_ID  Order_Date Customer_ID       Customer_Name  Gender   Age Age_Group      City          State Region  Latitude  Longitude Product_ID  \
# 0  ORD101152  2024-03-21   CUST13416           Tanvi Rao  Female 23.00     18-25     Kochi         Kerala  South      9.93      76.27      P1042
# 1  ORD107594  2025-01-31   CUST12988  Swapnil Chatterjee  Female 44.00     36-45  Gurugram        Haryana  North     28.46      77.03      P1067
# 2  ORD109386  2025-05-15   CUST11826      Karan Deshmukh  Female 38.00     36-45       NaN        Gujarat   West     21.17      72.83      P1058
# 3  ORD102186  2024-05-21   CUST12825        Swapnil Bhat    Male 32.00     26-35    Mumbai    Maharashtra   West     19.08      72.88      P1041
# 4  ORD113618  2025-11-08   CUST12560        Imran Sharma  Female 42.00     36-45    Kanpur  Uttar Pradesh  North     26.45      80.33      P1015
#
#                Product_Name    Category      Sub_Category  Quantity  Unit_Price  Discount_Percentage     Sales      Cost  Profit  Profit_Margin  \
# 0      Tata Tea Premium 1kg     Grocery         Beverages         2      645.40                 7.70  1,191.71  1,069.15  122.56          10.28
# 1    Blue Star 1T Window AC  Appliances  Air Conditioners         2   36,248.75                15.60 61,199.04 60,540.81  658.23           1.08
# 2     Data Science Handbook       Books          Academic         3    1,733.50                 7.90  4,791.23  3,946.73  844.50          17.63
# 3  Fortune Sunflower Oil 5L     Grocery           Staples         3    1,373.75                 4.00  3,955.20  3,640.56  314.64           7.96
# 4     W Printed Palazzo Set     Fashion  Women's Clothing         2    2,260.70                25.40  3,373.77  2,501.81 -495.79         -14.70
#
#      Payment_Method Order_Status  Delivery_Days  Customer_Rating Customer_Segment Device_Type
# 0               UPI    Delivered           5.00             4.20          Premium  Mobile App
# 1       Credit Card    Delivered           3.00             4.50        Corporate  Mobile App
# 2               UPI    Delivered           2.00             4.80          Regular  Mobile Web
# 3            Wallet    Delivered           3.00             5.00          Premium      Tablet
# 4  Cash on Delivery     Returned           5.00             2.90          Regular  Mobile App

# %%
df_raw.shape
# Out:
# (15120, 29)

# %%
# step2 : Data cleaning

# %%
for i in df_raw.columns:
    print (i)
# Out:
# Order_ID
# Order_Date
# Customer_ID
# Customer_Name
# Gender
# Age
# Age_Group
# City
# State
# Region
# Latitude
# Longitude
# Product_ID
# Product_Name
# Category
# Sub_Category
# Quantity
# Unit_Price
# Discount_Percentage
# Sales
# Cost
# Profit
# Profit_Margin
# Payment_Method
# Order_Status
# Delivery_Days
# Customer_Rating
# Customer_Segment
# Device_Type

# %%
df_raw.isnull().sum()
# Out:
# Order_ID               0
# Order_Date             0
# Customer_ID            0
# Customer_Name          0
# Gender                 0
# Age                    0
# Age_Group              0
# City                   0
# State                  0
# Region                 0
# Latitude               0
# Longitude              0
# Product_ID             0
# Product_Name           0
# Category               0
# Sub_Category           0
# Quantity               0
# Unit_Price             0
# Discount_Percentage    0
# Sales                  0
# Cost                   0
# Profit                 0
# Profit_Margin          0
# Payment_Method         0
# Order_Status           0
# Delivery_Days          0
# Customer_Rating        0
# Customer_Segment       0
# Device_Type            0
# dtype: int64

# %%
df_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13540 entries, 0 to 13539
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order_ID             13540 non-null  str
#  1   Order_Date           13540 non-null  datetime64[us]
#  2   Customer_ID          13540 non-null  str
#  3   Customer_Name        13540 non-null  str
#  4   Gender               13540 non-null  str
#  5   Age                  13540 non-null  int64
#  6   Age_Group            13540 non-null  str
#  7   City                 13540 non-null  str
#  8   State                13540 non-null  str
#  9   Region               13540 non-null  str
#  10  Latitude             13540 non-null  float64
#  11  Longitude            13540 non-null  float64
#  12  Product_ID           13540 non-null  str
#  13  Product_Name         13540 non-null  str
#  14  Category             13540 non-null  str
#  15  Sub_Category         13540 non-null  str
#  16  Quantity             13540 non-null  int64
#  17  Unit_Price           13540 non-null  float64
#  18  Discount_Percentage  13540 non-null  float64
#  19  Sales                13540 non-null  float64
#  20  Cost                 13540 non-null  float64
#  21  Profit               13540 non-null  float64
#  22  Profit_Margin        13540 non-null  float64
#  23  Payment_Method       13540 non-null  str
#  24  Order_Status         13540 non-null  str
#  25  Delivery_Days        13540 non-null  int64
#  26  Customer_Rating      13540 non-null  float64
#  27  Customer_Segment     13540 non-null  str
#  28  Device_Type          13540 non-null  str
# dtypes: datetime64[us](1), float64(9), int64(3), str(16)
# memory usage: 3.0 MB

# %%
df_raw.describe().T
# Out:
#                         count                        mean                  min                  25%                  50%                  75%  \
# Order_Date              13540  2025-01-31 21:55:46.883308  2024-01-01 00:00:00  2024-08-21 00:00:00  2025-01-25 12:00:00  2025-08-17 00:00:00
# Age                 13,540.00                       34.29                 1.00                27.00                34.00                41.00
# Latitude            13,540.00                       20.34                 8.52                13.08                19.08                26.45
# Longitude           13,540.00                       77.54                72.57                73.86                77.10                78.49
# Quantity            13,540.00                        1.95                -3.00                 1.00                 1.00                 2.00
# Unit_Price          13,540.00                    7,258.64               122.40               782.44             1,919.74             5,224.56
# Discount_Percentage 13,540.00                       15.27                 0.00                 9.10                15.10                21.10
# Sales               13,540.00                    8,148.09               115.39             1,273.65             2,467.66             6,628.60
# Cost                13,540.00                    7,453.03               105.82             1,003.49             1,970.96             5,348.60
# Profit              13,540.00                      541.02           -23,504.19                53.47               336.13               874.27
# Profit_Margin       13,540.00                       14.26               -51.78                 3.69                14.75                26.11
# Delivery_Days       13,540.00                        3.95                 1.00                 3.00                 4.00                 5.00
# Customer_Rating     13,540.00                        4.36                 0.00                 4.10                 4.40                 4.80
#
#                                      max       std
# Order_Date           2025-12-31 00:00:00       NaN
# Age                               200.00     10.63
# Latitude                           30.90      6.08
# Longitude                          91.74      4.08
# Quantity                          206.00      4.62
# Unit_Price                    890,296.75 15,626.47
# Discount_Percentage                49.20      8.47
# Sales                         204,868.73 15,366.97
# Cost                          219,886.83 15,126.06
# Profit                         23,402.87  1,759.01
# Profit_Margin                      51.39     15.95
# Delivery_Days                      59.00      2.06
# Customer_Rating                     7.50      0.54

# %% [markdown]
# **Red flags already visible in `.describe()`**
#
# | Column | Suspicious value | Why it matters |
# |---|---|---|
# | `Quantity` | minimum is **negative** and maximum is in the hundreds | Negative units are impossible; huge quantities are data-entry glitches |
# | `Age` | minimum near **1**, maximum **200** | Not a valid customer age |
# | `Customer_Rating` | maximum above **5** | The rating scale is 1-5 |
# | `Delivery_Days` | maximum near **60** | Almost certainly stuck/lost shipments |
# | `Unit_Price` | maximum far above the highest catalogue price | Price-feed error |
#
# We will handle each of these explicitly in the cleaning section.

# %%
# how many unique values each has and which VALUE appears most often.
df_raw.describe(include="object").T
# Out:
# C:\Users\Tanuja\AppData\Local\Temp\ipykernel_26488\3580460054.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df_raw.describe(include="object").T
#                   count unique                      top   freq
# Order_ID          13540  13540                ORD101152      1
# Customer_ID       13540   3022                CUST12879     32
# Customer_Name     13540   1207              Shruti Iyer     62
# Gender            13540      2                     Male   7420
# Age_Group         13540      5                    26-35   4496
# City              13540     25                   Mumbai   1307
# State             13540     20              Maharashtra   2709
# Region            13540      6                    South   4355
# Product_ID        13540     67                    P1043    349
# Product_Name      13540     67  Bru Instant Coffee 200g    349
# Category          13540     15                  Fashion   3126
# Sub_Category      13540     33                  Staples    947
# Payment_Method    13540     12                      UPI   5249
# Order_Status      13540      4                Delivered  11624
# Customer_Segment  13540      4                  Regular   4519
# Device_Type       13540      4               Mobile App   7874

# %%
print("unique values per column:")
df_raw.nunique().sort_values(ascending=False)
# Out:
# unique values per column:
# Order_ID               13540
# Sales                  13393
# Cost                   13379
# Profit                 13109
# Unit_Price             12617
# Profit_Margin           5561
# Customer_ID             3022
# Customer_Name           1207
# Order_Date               731
# Discount_Percentage      415
# Product_Name              67
# Product_ID                67
# Age                       53
# Customer_Rating           39
# Sub_Category              33
# Quantity                  27
# Longitude                 25
# City                      25
# Latitude                  25
# State                     20
# Delivery_Days             18
# Category                  15
# Payment_Method            12
# Region                     6
# Age_Group                  5
# Customer_Segment           4
# Order_Status               4
# Device_Type                4
# Gender                     2
# dtype: int64

# %%
# handle null values

# %%
df_raw.dropna(inplace=True,ignore_index=True)

# %%
df_raw.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df_raw.shape
# Out:
# (13540, 29)

# %%
  # change data types of date column

# %%
df_raw['Order_Date']=pd.to_datetime(df_raw['Order_Date'])

# %%
df_raw.dtypes
# Out:
# Order_ID                          str
# Order_Date             datetime64[us]
# Customer_ID                       str
# Customer_Name                     str
# Gender                            str
# Age                             int64
# Age_Group                         str
# City                              str
# State                             str
# Region                            str
# Latitude                      float64
# Longitude                     float64
# Product_ID                        str
# Product_Name                      str
# Category                          str
# Sub_Category                      str
# Quantity                        int64
# Unit_Price                    float64
# Discount_Percentage           float64
# Sales                         float64
# Cost                          float64
# Profit                        float64
# Profit_Margin                 float64
# Payment_Method                    str
# Order_Status                      str
# Delivery_Days                   int64
# Customer_Rating               float64
# Customer_Segment                  str
# Device_Type                       str
# dtype: object

# %%
df_raw['Age']=df_raw['Age'].astype('int64') 
df_raw['Delivery_Days']=df_raw['Delivery_Days'].astype('int64')

# %%
df_raw.dtypes
# Out:
# Order_ID                          str
# Order_Date             datetime64[us]
# Customer_ID                       str
# Customer_Name                     str
# Gender                            str
# Age                             int64
# Age_Group                         str
# City                              str
# State                             str
# Region                            str
# Latitude                      float64
# Longitude                     float64
# Product_ID                        str
# Product_Name                      str
# Category                          str
# Sub_Category                      str
# Quantity                        int64
# Unit_Price                    float64
# Discount_Percentage           float64
# Sales                         float64
# Cost                          float64
# Profit                        float64
# Profit_Margin                 float64
# Payment_Method                    str
# Order_Status                      str
# Delivery_Days                   int64
# Customer_Rating               float64
# Customer_Segment                  str
# Device_Type                       str
# dtype: object

# %%
def get_nunique(df):
    for i in df.columns:
        if df[i].dtype=='str':
            print(df[i].unique())

# %%
get_nunique(df_raw[['Gender','Region']])
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
# <StringArray>
# ['South', 'North', 'West', 'Northeast', 'East', 'Central']
# Length: 6, dtype: str

# %%
df_raw.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 109 are duplicates

# %%
df_raw.drop_duplicates(inplace=True,ignore_index=True)

# %%
df_raw.shape
# Out:
# (13540, 29)

# %%
# order id

# %%
df_raw['Order_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
# replace values

# %%
df_raw.describe(include="object").T
# Out:
# C:\Users\Tanuja\AppData\Local\Temp\ipykernel_26488\3663497146.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df_raw.describe(include="object").T
#                   count unique                      top   freq
# Order_ID          13540  13540                ORD101152      1
# Customer_ID       13540   3022                CUST12879     32
# Customer_Name     13540   1207              Shruti Iyer     62
# Gender            13540      2                     Male   7420
# Age_Group         13540      5                    26-35   4496
# City              13540     25                   Mumbai   1307
# State             13540     20              Maharashtra   2709
# Region            13540      6                    South   4355
# Product_ID        13540     67                    P1043    349
# Product_Name      13540     67  Bru Instant Coffee 200g    349
# Category          13540     15                  Fashion   3126
# Sub_Category      13540     33                  Staples    947
# Payment_Method    13540     12                      UPI   5249
# Order_Status      13540      4                Delivered  11624
# Customer_Segment  13540      4                  Regular   4519
# Device_Type       13540      4               Mobile App   7874

# %%
df_raw['Gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df_raw=df_raw.replace({'Gender':{'F':'Female','M':'Male','male':'Male','female':'Female'}})

# %%
df_raw['Gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df_raw.shape
# Out:
# (13540, 29)

# %%
get_nunique(df_raw)
# Out:
# <StringArray>
# ['ORD101152', 'ORD107594', 'ORD102186', 'ORD113618', 'ORD109118', 'ORD104054', 'ORD101842', 'ORD109287', 'ORD106139', 'ORD101749',
#  ...
#  'ORD107567', 'ORD111450', 'ORD101373', 'ORD113928', 'ORD100920', 'ORD105700', 'ORD110743', 'ORD100538', 'ORD109413', 'ORD112464']
# Length: 13540, dtype: str
# <StringArray>
# ['CUST13416', 'CUST12988', 'CUST12825', 'CUST12560', 'CUST11485', 'CUST12272', 'CUST11168', 'CUST12020', 'CUST10513', 'CUST11617',
#  ...
#  'CUST10107', 'CUST13496', 'CUST10682', 'CUST13519', 'CUST13497', 'CUST12836', 'CUST12956', 'CUST13558', 'CUST10060', 'CUST11726']
# Length: 3022, dtype: str
# <StringArray>
# [         'Tanvi Rao', 'Swapnil Chatterjee',       'Swapnil Bhat',       'Imran Sharma',      'Deepak Mishra',         'Harsh Bose',  'Shruti Chatterjee',
#          'Yash Joshi',       'Farhan Patil',      'Rajesh Sharma',
#  ...
#          'Rahul Gill',      'Tejas Chauhan',  'Siddharth Chauhan',        'Karan Menon',       'Sanjana Nair',     'Arjun Kulkarni',       'Meera Pandey',
#          'Riya Reddy',    'Ritu Chatterjee',    'Siddharth Yadav']
# Length: 1207, dtype: str
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
# <StringArray>
# ['18-25', '36-45', '26-35', '46-60', '60+']
# Length: 5, dtype: str
# <StringArray>
# [             'Kochi',           'Gurugram',             'Mumbai',             'Kanpur',           'Guwahati',        'Bhubaneswar',           'Ludhiana',
#             'Chennai',          'Hyderabad',          'Bengaluru',              'Delhi',          'Ahmedabad',              'Surat',               'Pune',
#             'Kolkata',             'Jaipur',             'Indore',             'Nagpur', 'Thiruvananthapuram',             'Mysuru',         'Coimbatore',
#          'Chandigarh',             'Bhopal',              'Patna',            'Lucknow']
# Length: 25, dtype: str
# <StringArray>
# [        'Kerala',        'Haryana',    'Maharashtra',  'Uttar Pradesh',          'Assam',         'Odisha',         'Punjab',     'Tamil Nadu',
#       'Telangana',      'Karnataka',          'Delhi',        'Gujarat',    'West Bengal',      'Rajasthan', 'Madhya Pradesh',      'karnataka',
#      'Chandigarh',          'Bihar',   ' Maharashtra',    'maharashtra']
# Length: 20, dtype: str
# <StringArray>
# ['South', 'North', 'West', 'Northeast', 'East', 'Central']
# Length: 6, dtype: str
# <StringArray>
# ['P1042', 'P1067', 'P1041', 'P1015', 'P1039', 'P1024', 'P1013', 'P1066', 'P1031', 'P1026', 'P1008', 'P1012', 'P1003', 'P1035', 'P1002', 'P1016', 'P1005',
#  'P1020', 'P1022', 'P1064', 'P1007', 'P1033', 'P1021', 'P1032', 'P1043', 'P1017', 'P1040', 'P1036', 'P1038', 'P1061', 'P1055', 'P1050', 'P1006', 'P1037',
#  'P1046', 'P1010', 'P1053', 'P1029', 'P1028', 'P1014', 'P1052', 'P1004', 'P1047', 'P1049', 'P1063', 'P1034', 'P1009', 'P1023', 'P1025', 'P1011', 'P1030',
#  'P1019', 'P1051', 'P1057', 'P1045', 'P1044', 'P1056', 'P1062', 'P1001', 'P1048', 'P1018', 'P1060', 'P1027', 'P1054', 'P1065', 'P1059', 'P1058']
# Length: 67, dtype: str
# <StringArray>
# [        'Tata Tea Premium 1kg',       'Blue Star 1T Window AC',     'Fortune Sunflower Oil 5L',        'W Printed Palazzo Set',
#          'Aashirvaad Atta 10kg',     'Godrej Interio Bookshelf',    'US Polo Assn Polo T-Shirt',         'Voltas 1.5T Split AC',
#    'Minimalist Vitamin C Serum',     'Prestige Pressure Cooker',              'Canon EOS 1500D',     'Allen Solly Formal Shirt',
#              'OnePlus Nord CE4',      'Lakme Absolute Lipstick',           'Samsung Galaxy M35',        'Fabindia Cotton Saree',
#         'Lenovo IdeaPad Slim 3',        'Fastrack Casual Watch',     'Hidesign Leather Handbag',     'Bajaj 20L Solo Microwave',
#                 'Sony WH-CH520',      'Mamaearth Onion Shampoo',    'Wildcraft Laptop Backpack',         'Cetaphil Moisturiser',
#       'Bru Instant Coffee 200g',            'Bata Formal Shoes',  'India Gate Basmati Rice 5kg', 'Maybelline Fit Me Foundation',
#               'Fogg Body Spray',     'Samsung 192L Single Door',           'India After Gandhi',           'Adidas Track Pants',
#              'boAt Rockerz 450',          'Nykaa Eau de Parfum',     'Maggi Noodles Pack of 12',               'Apple Watch SE',
#               'The White Tiger',         'Pepperfry Table Lamp',           'Chumbak Wall Clock',          'Biba Anarkali Kurta',
#                'SG Cricket Kit',               'HP Pavilion 15',       'Kore Dumbbell Set 20kg',        'Nivia Football Jersey',
#        'Whirlpool 7kg Top Load',           'L'Oreal Hair Serum',         'Noise ColorFit Pro 5',         'Nilkamal Study Table',
#       'Sleepwell Foam Mattress',        'Levi's Slim Fit Jeans',       'Bombay Dyeing Bedsheet',       'Titan Neo Analog Watch',
#        'Decathlon Camping Tent',        'NCERT Class 12 Bundle',       'MTR Ready to Eat Combo',       'Haldiram Namkeen Combo',
#                 'Atomic Habits',         'IFB 6.5kg Front Load',             'Redmi Note 13 5G',      'Cockatoo Exercise Cycle',
#            'Puma Running Shoes',   'LG 260L Double Door Fridge',       'Milton Steel Casserole',                    'Shantaram',
#       'IFB 25L Convection Oven',    'Amar Chitra Katha Box Set',        'Data Science Handbook']
# Length: 67, dtype: str
# <StringArray>
# [         'Grocery',       'Appliances',          'Fashion', 'Home & Furniture',           'Beauty',      'Electronics',     ' Electronics',
#             'Books',           'Sports',        ' Fashion ',      'electronics',      'ELECTRONICS',          'grocery',          'fashion',
#           'GROCERY']
# Length: 15, dtype: str
# <StringArray>
# [        'Beverages',  'Air Conditioners',           'Staples',  'Women's Clothing',         'Furniture',    'Men's Clothing',          'Skincare',
#        'Kitchenware',           'Cameras',       'Smartphones',            'Makeup',           'Laptops',           'Watches',              'Bags',
#         'Microwaves',        'Headphones',          'Haircare',          'Footwear',        'Fragrances',     'Refrigerators',       'Non-Fiction',
#         'Sportswear',     'Packaged Food',     'Smart Watches',           'Fiction',        'Home Decor',      'Outdoor Gear', 'Fitness Equipment',
#   'Washing Machines',           'Bedding',          'Academic',            'Snacks',  'Children's Books']
# Length: 33, dtype: str
# <StringArray>
# ['UPI', 'Credit Card', 'Wallet', 'Cash on Delivery', 'EMI', 'Debit Card', 'Net Banking', 'cash on delivery', 'Upi', 'COD', 'UPI ', 'upi']
# Length: 12, dtype: str
# <StringArray>
# ['Delivered', 'Returned', 'Cancelled', 'Shipped']
# Length: 4, dtype: str
# <StringArray>
# ['Premium', 'Corporate', 'Regular', 'Budget']
# Length: 4, dtype: str
# <StringArray>
# ['Mobile App', 'Tablet', 'Desktop', 'Mobile Web']
# Length: 4, dtype: str

# %%
text_cols = ["Gender", "City", "State", "Region", "Category", "Sub_Category",
             "Payment_Method", "Order_Status", "Customer_Segment", "Device_Type",
             "Product_Name", "Age_Group"]

# %%
# removes extra spaces

# %%
for c in text_cols:
    df_raw[c]=df_raw[c].astype(str).str.strip()
    df_raw[c]=df_raw[c].replace({"nan":np.nan,"None":np.nan})

# %%
df_raw.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df_raw["Category"].unique()
# Out:
# <StringArray>
# [         'Grocery',       'Appliances',          'Fashion', 'Home & Furniture',           'Beauty',      'Electronics',            'Books',
#            'Sports',      'electronics',      'ELECTRONICS',          'grocery',          'fashion',          'GROCERY']
# Length: 13, dtype: str

# %%
for c in text_cols:
    df_raw[c]=df_raw[c].str.title()

# %%
df_raw["Category"].unique()
# Out:
# <StringArray>
# ['Grocery', 'Appliances', 'Fashion', 'Home & Furniture', 'Beauty', 'Electronics', 'Books', 'Sports']
# Length: 8, dtype: str

# %%
df_raw["Payment_Method"].unique()
# Out:
# <StringArray>
# ['Upi', 'Credit Card', 'Wallet', 'Cash On Delivery', 'Emi', 'Debit Card', 'Net Banking', 'Cod']
# Length: 8, dtype: str

# %%
df_raw=df_raw.replace({'Payment_Method':{"Cod":"Cash On Delivery"}})

# %%
df_raw["Payment_Method"].unique()
# Out:
# <StringArray>
# ['Upi', 'Credit Card', 'Wallet', 'Cash On Delivery', 'Emi', 'Debit Card', 'Net Banking']
# Length: 7, dtype: str

# %%
for i in df_raw["State"].unique():
    print(i)
# Out:
# Kerala
# Haryana
# Maharashtra
# Uttar Pradesh
# Assam
# Odisha
# Punjab
# Tamil Nadu
# Telangana
# Karnataka
# Delhi
# Gujarat
# West Bengal
# Rajasthan
# Madhya Pradesh
# Chandigarh
# Bihar

# %%
# all ok in state column

# %%
df_raw.describe().T
# Out:
#                         count                        mean                  min                  25%                  50%                  75%  \
# Order_Date              13540  2025-01-31 21:55:46.883308  2024-01-01 00:00:00  2024-08-21 00:00:00  2025-01-25 12:00:00  2025-08-17 00:00:00
# Age                 13,540.00                       34.29                 1.00                27.00                34.00                41.00
# Latitude            13,540.00                       20.34                 8.52                13.08                19.08                26.45
# Longitude           13,540.00                       77.54                72.57                73.86                77.10                78.49
# Quantity            13,540.00                        1.95                -3.00                 1.00                 1.00                 2.00
# Unit_Price          13,540.00                    7,258.64               122.40               782.44             1,919.74             5,224.56
# Discount_Percentage 13,540.00                       15.27                 0.00                 9.10                15.10                21.10
# Sales               13,540.00                    8,148.09               115.39             1,273.65             2,467.66             6,628.60
# Cost                13,540.00                    7,453.03               105.82             1,003.49             1,970.96             5,348.60
# Profit              13,540.00                      541.02           -23,504.19                53.47               336.13               874.27
# Profit_Margin       13,540.00                       14.26               -51.78                 3.69                14.75                26.11
# Delivery_Days       13,540.00                        3.95                 1.00                 3.00                 4.00                 5.00
# Customer_Rating     13,540.00                        4.36                 0.00                 4.10                 4.40                 4.80
#
#                                      max       std
# Order_Date           2025-12-31 00:00:00       NaN
# Age                               200.00     10.63
# Latitude                           30.90      6.08
# Longitude                          91.74      4.08
# Quantity                          206.00      4.62
# Unit_Price                    890,296.75 15,626.47
# Discount_Percentage                49.20      8.47
# Sales                         204,868.73 15,366.97
# Cost                          219,886.83 15,126.06
# Profit                         23,402.87  1,759.01
# Profit_Margin                      51.39     15.95
# Delivery_Days                      59.00      2.06
# Customer_Rating                     7.50      0.54

# %%
df_raw[df_raw["Quantity"]<=0]
# Out:
#         Order_ID Order_Date Customer_ID    Customer_Name  Gender  Age Age_Group       City        State Region  Latitude  Longitude Product_ID  \
# 4151   ORD101239 2024-03-26   CUST13011     Manish Verma  Female   57     46-60     Jaipur    Rajasthan  North     26.91      75.79      P1046
# 5181   ORD106642 2024-12-09   CUST10361       Rahul Kaur    Male   29     26-35    Chennai   Tamil Nadu  South     13.08      80.27      P1025
# 5276   ORD104712 2024-10-03   CUST13011     Manish Verma  Female   57     46-60     Jaipur    Rajasthan  North     26.91      75.79      P1001
# 6511   ORD103083 2024-07-15   CUST10894  Suresh Deshmukh    Male   27     26-35     Mumbai  Maharashtra   West     19.08      72.88      P1006
# 12251  ORD102900 2024-07-06   CUST11252      Vikram Iyer  Female   46     46-60  Bengaluru    Karnataka  South     12.97      77.59      P1018
#
#                    Product_Name          Category   Sub_Category  Quantity  Unit_Price  Discount_Percentage     Sales      Cost   Profit  Profit_Margin  \
# 4151   Maggi Noodles Pack Of 12           Grocery  Packaged Food        -3      167.24                12.20    440.55    442.01    -1.46          -0.33
# 5181    Sleepwell Foam Mattress  Home & Furniture      Furniture        -1   11,160.79                 8.30 10,239.15  7,905.30 2,333.85          22.79
# 5276           Redmi Note 13 5G       Electronics    Smartphones        -2   17,497.14                18.70 14,226.24 14,918.00  -691.76          -4.86
# 6511           Boat Rockerz 450       Electronics     Headphones        -3    2,149.37                 2.50  2,094.69  1,485.02   609.67          29.11
# 12251        Puma Running Shoes           Fashion       Footwear        -1    4,928.86                15.30 16,702.54 13,036.50 3,666.04          21.95
#
#          Payment_Method Order_Status  Delivery_Days  Customer_Rating Customer_Segment Device_Type
# 4151   Cash On Delivery    Delivered              4             4.20          Premium  Mobile App
# 5181                Upi    Delivered              3             4.60          Regular  Mobile App
# 5276        Net Banking    Delivered              3             5.00          Premium  Mobile App
# 6511   Cash On Delivery    Delivered              3             4.80          Regular  Mobile Web
# 12251               Upi    Delivered              4             4.50          Regular  Mobile App

# %%
df_raw[df_raw["Quantity"]<=0].shape
# Out:
# (5, 29)

# %%
df_raw=df_raw[~(df_raw["Quantity"]<=0)]

# %%
df_raw.shape
# Out:
# (13535, 29)

# %%
df_raw[( df_raw["Age"] < 15 ) | ( df_raw["Age"] > 90 ) ]
# Out:
#         Order_ID Order_Date Customer_ID     Customer_Name  Gender  Age Age_Group     City        State Region  Latitude  Longitude Product_ID  \
# 150    ORD102769 2024-06-28   CUST12692      Ishita Joshi  Female  150     36-45    Delhi        Delhi  North     28.70      77.10      P1045
# 1199   ORD113766 2025-11-13   CUST11823  Swapnil Banerjee  Female  150     46-60  Kolkata  West Bengal   East     22.57      88.36      P1013
# 6781   ORD109778 2025-06-04   CUST10864        Gaurav Das  Female  150     26-35    Delhi        Delhi  North     28.70      77.10      P1036
# 8173   ORD103025 2024-07-12   CUST10179      Rahul Sheikh  Female    1     36-45    Delhi        Delhi  North     28.70      77.10      P1066
# 8685   ORD102582 2024-06-15   CUST12966  Harsh Chatterjee  Female  200     36-45     Pune  Maharashtra   West     18.52      73.86      P1030
# 10346  ORD103427 2024-08-04   CUST11521      Ishita Verma  Female  200     36-45    Delhi        Delhi  North     28.70      77.10      P1049
# 11095  ORD114673 2025-12-18   CUST10220       Arjun Joshi  Female    1     36-45   Mumbai  Maharashtra   West     19.08      72.88      P1012
#
#                        Product_Name          Category      Sub_Category  Quantity  Unit_Price  Discount_Percentage     Sales      Cost   Profit  \
# 150          Mtr Ready To Eat Combo           Grocery     Packaged Food         1      584.45                 0.00    584.45    491.81    92.64
# 1199      Us Polo Assn Polo T-Shirt           Fashion    Men'S Clothing         5    1,792.40                27.50  6,496.55  5,054.73 1,441.82
# 6781   Maybelline Fit Me Foundation            Beauty            Makeup         1    1,103.58                 4.40  1,054.60    593.02   461.58
# 8173           Voltas 1.5T Split Ac        Appliances  Air Conditioners         2   45,728.56                11.10 81,288.04 72,424.00 8,864.04
# 8685         Bombay Dyeing Bedsheet  Home & Furniture           Bedding         2    1,486.31                11.20  2,640.25  2,030.69   609.56
# 10346         Nivia Football Jersey            Sports        Sportswear         3    1,535.68                12.10  4,050.19  2,967.27 1,082.92
# 11095      Allen Solly Formal Shirt           Fashion    Men'S Clothing         1    1,349.14                22.70  1,042.40    778.96   263.44
#
#        Profit_Margin Payment_Method Order_Status  Delivery_Days  Customer_Rating Customer_Segment Device_Type
# 150            15.85            Upi    Delivered              2             4.90          Premium  Mobile App
# 1199           22.19    Credit Card    Delivered              3             4.70        Corporate  Mobile App
# 6781           43.77            Upi    Delivered              5             3.60           Budget     Desktop
# 8173           10.90            Emi    Delivered              2             5.00          Regular  Mobile App
# 8685           23.09            Upi    Delivered              5             4.00          Premium      Tablet
# 10346          26.74     Debit Card    Delivered              4             4.70          Regular     Desktop
# 11095          25.27    Credit Card    Delivered              3             4.60           Budget  Mobile App

# %%
# 5 records where quantity is negative
# 7 records where age is less than 15 and grater than 90

# %%
df_raw=df_raw[( df_raw["Age"] > 15 ) & ( df_raw["Age"] < 90 ) ]

# %%
df_raw.shape
# Out:
# (13528, 29)

# %%
df_raw[(df_raw["Customer_Rating"]<1) | (df_raw["Customer_Rating"]>5 )]
# Out:
#         Order_ID Order_Date Customer_ID    Customer_Name  Gender  Age Age_Group       City        State Region  Latitude  Longitude Product_ID  \
# 2064   ORD107449 2025-01-21   CUST10894  Suresh Deshmukh    Male   27     26-35     Mumbai  Maharashtra   West     19.08      72.88      P1037
# 6934   ORD101914 2024-05-06   CUST11684      Tanvi Verma    Male   32     26-35    Chennai   Tamil Nadu  South     13.08      80.27      P1042
# 6989   ORD102909 2024-07-06   CUST11681      Tejas Naidu  Female   47     46-60      Delhi        Delhi  North     28.70      77.10      P1049
# 7708   ORD100272 2024-01-21   CUST11352      Nikhil Khan  Female   32     26-35     Mumbai  Maharashtra   West     19.08      72.88      P1014
# 13151  ORD105666 2024-11-01   CUST12383       Meera Nair  Female   18     18-25  Hyderabad    Telangana  South     17.39      78.49      P1011
# 13479  ORD100093 2024-01-07   CUST10060      Manish Iyer    Male   33     26-35      Delhi        Delhi  North     28.70      77.10      P1043
#
#                   Product_Name Category      Sub_Category  Quantity  Unit_Price  Discount_Percentage    Sales     Cost   Profit  Profit_Margin Payment_Method  \
# 2064       Nykaa Eau De Parfum   Beauty        Fragrances         2      996.22                21.30 1,568.73 1,025.51   543.22          34.63    Credit Card
# 6934      Tata Tea Premium 1Kg  Grocery         Beverages         2      533.20                12.00   938.32   934.13     4.19           0.45            Upi
# 6989     Nivia Football Jersey   Sports        Sportswear         1    1,275.81                15.20 1,081.65   831.71    -6.28          -0.58    Credit Card
# 7708       Biba Anarkali Kurta  Fashion  Women'S Clothing         3    1,729.57                21.70 4,064.69 2,873.42 1,191.27          29.31    Credit Card
# 13151    Levi'S Slim Fit Jeans  Fashion    Men'S Clothing         1    3,385.16                 9.10 3,078.71 1,986.04 1,092.67          35.49    Net Banking
# 13479  Bru Instant Coffee 200G  Grocery         Beverages         2      499.63                10.30   895.86   796.21    99.65          11.12            Upi
#
#       Order_Status  Delivery_Days  Customer_Rating Customer_Segment Device_Type
# 2064       Shipped              3             0.00          Regular  Mobile App
# 6934     Delivered              4             6.00           Budget  Mobile App
# 6989     Cancelled              1             6.00           Budget  Mobile App
# 7708     Delivered              3             0.00          Regular  Mobile App
# 13151    Delivered              2             7.50           Budget      Tablet
# 13479    Delivered              3             6.00           Budget  Mobile App

# %%
df_raw=df_raw[(df_raw["Customer_Rating"]>=1) & (df_raw["Customer_Rating"]<=5 )]

# %%
df_raw.shape
# Out:
# (13522, 29)

# %%
df_raw[df_raw["Delivery_Days"] > 30].count()
# Out:
# Order_ID               8
# Order_Date             8
# Customer_ID            8
# Customer_Name          8
# Gender                 8
# Age                    8
# Age_Group              8
# City                   8
# State                  8
# Region                 8
# Latitude               8
# Longitude              8
# Product_ID             8
# Product_Name           8
# Category               8
# Sub_Category           8
# Quantity               8
# Unit_Price             8
# Discount_Percentage    8
# Sales                  8
# Cost                   8
# Profit                 8
# Profit_Margin          8
# Payment_Method         8
# Order_Status           8
# Delivery_Days          8
# Customer_Rating        8
# Customer_Segment       8
# Device_Type            8
# dtype: int64

# %%
df_raw=df_raw[df_raw["Delivery_Days"] <= 30]

# %%
df_raw.shape
# Out:
# (13514, 29)

# %%
# Negative or zero Quantity       : 4
# Age below 15 or above 90        : 7
# Rating outside the 1-5 scale    : 6
# Delivery_Days above 30          : 8

# %%
df=df_raw.copy()

# %%
# final clean dataframe

# %%
df.to_csv('clean_sales_ecommerce.csv')

# %%
# EDA (Exploratory Data Analysis)
